# %%
import tushare as ts

# %%
token = '14fb917ff65d6d59dd1ace7064fb3091975ce2035a9d12acd314d610'

# %%
import sys

# %%
sys.executable
# Out:
# 'F:\\conda\\envs\\afan_test\\python.exe'

# %%
pro = ts.pro_api(token)

# %%
df = pro.opt_daily(trade_date='20220331')

# %%
df
# Out:
#                 ts_code trade_date exchange  pre_settle  pre_close   open  \
# 0     IO2204-C-3550.CFX   20220331    CFFEX       699.6      665.6  673.2
# 1     IO2204-C-3600.CFX   20220331    CFFEX       650.2      610.6  619.8
# 2     IO2204-C-3650.CFX   20220331    CFFEX       600.6      599.0    NaN
# 3     IO2204-C-3700.CFX   20220331    CFFEX       551.2      549.4  541.0
# 4     IO2204-C-3750.CFX   20220331    CFFEX       503.2      471.8    NaN
# ...                 ...        ...      ...         ...        ...    ...
# 7995  PP2210-P-7500.DCE   20220331      DCE        57.5       57.5    0.0
# 7996  PP2210-P-7600.DCE   20220331      DCE        69.5       69.5    0.0
# 7997  PP2210-P-7700.DCE   20220331      DCE        84.0       84.0    0.0
# 7998  PP2210-P-7800.DCE   20220331      DCE       100.5      100.5    0.0
# 7999  PP2210-P-7900.DCE   20220331      DCE       119.0      119.0    0.0
#
#        high    low  close  settle   vol  amount     oi
# ...

# %%
df[]
